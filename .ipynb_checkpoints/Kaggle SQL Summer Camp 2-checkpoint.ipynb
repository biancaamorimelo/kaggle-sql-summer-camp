# %% [markdown]
# **Participant:** Bianca Karla Amorim

# %%
# Set your own project id here
PROJECT_ID = 'hidden-cosmos-240318'
  
from google.cloud import bigquery
client = bigquery.Client(project=PROJECT_ID, location="US")

# %%
# Construct a reference to the "openaq" dataset
dataset_ref = client.dataset("openaq", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "openaq" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there's only one!)
for table in tables:  
    print(table.table_id)
# Out:
# global_air_quality

# %%
# Construct a reference to the "global_air_quality" table
table_ref = dataset_ref.table("global_air_quality")

# API request - fetch the table
table = client.get_table(table_ref)

# %%
# Preview the first five lines of the "global_air_quality" table
client.list_rows(table, max_results=10).to_dataframe()
# Out:
#                                    location          ...           averaged_over_in_hours
# 0             BTM Layout, Bengaluru - KSPCB          ...                             0.25
# 1             BTM Layout, Bengaluru - KSPCB          ...                             0.25
# 2             BTM Layout, Bengaluru - KSPCB          ...                             0.25
# 3             BTM Layout, Bengaluru - KSPCB          ...                             0.25
# 4             BTM Layout, Bengaluru - KSPCB          ...                             0.25
# 5  BWSSB Kadabesanahalli, Bengaluru - KSPCB          ...                             0.25
# 6  BWSSB Kadabesanahalli, Bengaluru - KSPCB          ...                             0.25
# 7                     BWSSB Kadabesanahalli          ...                             0.25
# 8  BWSSB Kadabesanahalli, Bengaluru - KSPCB          ...                             0.25
# 9  BWSSB Kadabesanahalli, Bengaluru - KSPCB          ...                             0.25
#
# [10 rows x 11 columns]

# %%
query = """
    SELECT city
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = 'US'
    """

# %%
# Create a "Client" object
client = bigquery.Client()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-7-7ce9183667c7> in <module>
#       1 # Create a "Client" object
# ----> 2 client = bigquery.Client()
#
# /root/.local/lib/python3.6/site-packages/sitecustomize.py in <lambda>(*args, **kwargs)
#      56         bq_client = bigquery.Client
#      57         bigquery.Client = lambda *args, **kwargs:  monkeypatch_bq(
# ---> 58             bq_client, *args, **kwargs)
#      59
#      60 init()
#
# /root/.local/lib/python3.6/site-packages/sitecustomize.py in monkeypatch_bq(bq_client, *args, **kwargs)
#      49                         print('Please ensure you have selected a BigQuery '
#      50                             'account in the Kernels Settings sidebar.')
# ---> 51                 return bq_client(*args, **kwargs)
#      52
#      53         # Monkey patches BigQuery client creation to use proxy or user-connected GCP account.
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info)
#     157     ):
#     158         super(Client, self).__init__(
# --> 159             project=project, credentials=credentials, _http=_http
#     160         )
#     161         self._connection = Connection(self, client_info=client_info)
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/client.py in __init__(self, project, credentials, _http)
#     225
#     226     def __init__(self, project=None, credentials=None, _http=None):
# --> 227         _ClientProjectMixin.__init__(self, project=project)
#     228         Client.__init__(self, credentials=credentials, _http=_http)
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/client.py in __init__(self, project)
#     177
#     178     def __init__(self, project=None):
# --> 179         project = self._determine_default(project)
#     180         if project is None:
#     181             raise EnvironmentError(
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/client.py in _determine_default(project)
#     192     def _determine_default(project):
#     193         """Helper:  use default project detection."""
# --> 194         return _determine_default_project(project)
#     195
#     196
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/_helpers.py in _determine_default_project(project)
#     184     """
#     185     if project is None:
# --> 186         _, project = google.auth.default()
#     187     return project
#     188
#
# /opt/conda/lib/python3.6/site-packages/google/auth/_default.py in default(scopes, request)
#     315             return credentials, effective_project_id
#     316
# --> 317     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %%
# Set up the query
query_job = client.query(query)

# %%
# API request - run the query, and return a pandas DataFrame
us_cities = query_job.to_dataframe()

# %%
# What five cities have the most measurements?
us_cities.city.value_counts().head()
# Out:
# Phoenix-Mesa-Scottsdale                     87
# Houston                                     82
# Los Angeles-Long Beach-Santa Ana            63
# New York-Northern New Jersey-Long Island    60
# Riverside-San Bernardino-Ontario            59
# Name: city, dtype: int64

# %%
# If you want multiple columns, you can select them with a comma between the names

# Question: What's up with the triple quotation marks (""")?
# Answer: These tell Python that everything inside them is a single string, even though we have line breaks in it. 
# The line breaks aren't necessary, but they make it easier to read your query.

query = """
        SELECT city, country
        FROM `bigquery-public-data.openaq.global_air_quality`
        WHERE country = 'US'
        """

# %%
# You can select all columns with a * like this
#query = """
     #   SELECT *
      #  FROM `bigquery-public-data.openaq.global_air_quality`
      #  WHERE country = 'US'
       # """

# %% [markdown]
# **Working with big datasets**
#
# We can estimate the size of any query before running it. To see how much data a query will scan, we create a QueryJobConfig object and set the dry_run parameter to True.

# %%
# Query to get the score column from every row where the type column has value "job"
query = """
        SELECT score, title
        FROM `bigquery-public-data.hacker_news.full`
        WHERE type = "job" 
        """

# %%
# Create a QueryJobConfig object to estimate size of query without running it
dry_run_config = bigquery.QueryJobConfig(dry_run=True)

# API request - dry run query to estimate costs
dry_run_query_job = client.query(query, job_config=dry_run_config)

print("This query will process {} bytes.".format(dry_run_query_job.total_bytes_processed))
# Out:
# This query will process 394890344 bytes.

# %% [markdown]
# You can also specify a parameter when running the query to limit how much data you are willing to scan. Here's an example with a low limit.

# %%
# Only run the query if it's less than 100 MB
ONE_HUNDRED_MB = 100*1000*1000
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_HUNDRED_MB)

# %%
# Set up the query (will only run if it's less than 100 MB)
safe_query_job = client.query(query, job_config=safe_config)

# API request - try to run the query, and return a pandas DataFrame
safe_query_job.to_dataframe()
# Out:
#        score                                              title
# 0        4.0                 Designer - Mixpanel Analytics [SF]
# 1       65.0  Rails developer needed for stealth/VC funded Y...
# 2       29.0  Profitable W'11 company looking for driven sal...
# 3       36.0  Posterous (YC08) is hiring an Analytics Engine...
# 4       35.0  Heyzap Hiring 4th Team Member (Engineer) [SF Y...
# 5       44.0  Where are the HN Designers/UX folk? GazeHawk (...
# 6       44.0  Help Heyzap (YC 09) make the biggest Android/i...
# 7       40.0  Posterous is hiring a Senior Infrastructure En...
# 8        2.0  [SF] Justin.tv needs front end web developer (...
# 9        7.0   Spend the Summer with BackType and True Ventures
# 10      30.0  [SF] Reble.FM is hiring. Looking for Ninjas. P...
# 11      36.0  Heyzap (YC09/USV) looking for a flash contractor.
# 12      34.0  Heysan looking for Java-developer   [San Franc...
# 13       2.0                         Airbnb - Frontend Engineer
# 14      21.0  [SF] MeetYou seeks additional cofounder to tak...
# 15     101.0  Posterous is hiring Rails, Infrastructure and ...
# 16       2.0                          Airbnb - Backend Engineer
# 17      11.0   Mixpanel Analytics looking for frontend engineer
# 18       9.0  [SF/NYC/Earth] Heysan! is hiring Javascript de...
# 19       4.0                       Airbnb hiring SEM specialist
# 20       8.0          Mixpanel (S09) hiring a Software Engineer
# 21     104.0  Stealth YC Startup Hiring System Software Engi...
# 22      18.0  Yet Another Javascript Engineer Job Posting (G...
# 23       9.0  Mixpanel is looking for a great frontend devel...
# 24      10.0                  Hipmunk is Hiring a Web Engineer.
# 25       7.0           Mixpanel is looking for a great designer
# 26      23.0                [SF] Justin.tv is hiring sys admins
# 27       5.0  [SF] Clickpass seeks HTML/CSS designer/illustr...
# 28       2.0  Web Engineer - Mixpanel - Scaling to the internet
# 29       6.0             CarWoo! seeking Senior Rails Developer
# ...      ...                                                ...
# 12032    3.0       Mixpanel is looking for a front-end engineer
# 12033    3.0                         Airbnb - Frontend Engineer
# 12034    3.0                 Airbnb - Fraud Management Engineer
# 12035    3.0                 Interns! - Mixpanel Analytics [SF]
# 12036    3.0                Tuxebo - Hiring London based hacker
# 12037    3.0   BackType Is Hiring Search And Software Engineers
# 12038    3.0                         Airbnb - Payments Engineer
# 12039    3.0               CarWoo! - Visual Experience Designer
# 12040    3.0  Justin.tv is hiring for technical and nontechn...
# 12041    3.0                 Airbnb - Fraud Management Engineer
# 12042    3.0                      Software Architect at Mertado
# 12043    3.0                  Loopt looking for product manager
# 12044    3.0     Software Engineer Intern at Mertado (YC W2010)
# 12045    3.0        Frontend Engineer - Mixpanel Analytics [SF]
# 12046    3.0             BackType — Software Developer (Intern)
# 12047    3.0                Airbnb - Email Marketing Specialist
# 12048    3.0                Airbnb hiring 3 front-end engineers
# 12049    3.0  Men wanted for hazardous journey: AdGrok (YC S...
# 12050    3.0                 Software Engineer at Opzi (YC S10)
# 12051    3.0                               Airbnb - UI Designer
# 12052    3.0                 Airbnb - User Acquisition Engineer
# 12053    3.0        Mixpanel hiring a software engineer [YCS09]
# 12054    3.0                   BackType is hiring a BD engineer
# 12055    3.0                     Web developer intern - Mertado
# 12056    3.0    YC startup looking for short-term contract help
# 12057    3.0                               WePay - Web Engineer
# 12058    3.0  Software Engineers Wanted (bounty: iPad for ea...
# 12059    3.0                         Airbnb - Frontend Engineer
# 12060    3.0                          Airbnb - Backend Engineer
# 12061    3.0   Mertado (venture funded) is hiring web engineers
#
# [12062 rows x 2 columns]

# %% [markdown]
# In this case, the query was cancelled, because the limit of 1 MB was exceeded. However, we can increase the limit to run the query successfully!

# %%
# Only run the query if it's less than 1 GB
ONE_GB = 1000*1000*1000
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_GB)

# Set up the query (will only run if it's less than 1 GB)
safe_query_job = client.query(query, job_config=safe_config)

# API request - try to run the query, and return a pandas DataFrame
job_post_scores = safe_query_job.to_dataframe()

# Print average score for job posts
job_post_scores.score.mean()
# Out:
# 1.9627923150482482
